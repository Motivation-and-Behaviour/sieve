# %%
from dotenv import load_dotenv

import bigger_picker.config as config
from bigger_picker.airtable import AirtableManager
from bigger_picker.asana import AsanaManager
from bigger_picker.batchtracker import BatchTracker
from bigger_picker.integration import IntegrationManager
from bigger_picker.openai import OpenAIManager
from bigger_picker.rayyan import RayyanManager

load_dotenv()
# Out:
# True

# %%
airtable = AirtableManager()
asana = AsanaManager()
openai = OpenAIManager()
rayyan = RayyanManager()
batchtracker = BatchTracker()
integration = IntegrationManager(
    asana_manager=asana,
    airtable_manager=airtable,
    openai_manager=openai,
    rayyan_manager=rayyan,
    batch_tracker=batchtracker,
    debug=True,
)

# %%
articles = airtable.tables["Articles"].all()
datasets = airtable.tables["Datasets"].all()
asana_tasks = asana.get_tasks(refresh=True)

# %%
tasks = {}

for task in asana.tasks:
    tasks[
        asana.get_custom_field_value(task, config.ASANA_CUSTOM_FIELD_IDS["BPIPD"])
        ] = task

# %%
datasets_dict = {dataset['id']: dataset for dataset in datasets}

# %%
articles_dict = {}
for article in articles:
  article_id = article['fields']['Rayyan ID']
  articles_dict[article_id] = articles_dict.get(article_id, 0) + 1

# %%
duplicates = {}
for article in articles:
    article_id = article['fields']['Rayyan ID']
    duplicates[article_id] = duplicates.get(article_id, []) + [article]

duplicates = {k: v for k, v in duplicates.items() if len(v) > 1}

# %%
unprocessed_duplicates = {}
for article_id, articles in duplicates.items():
  print(article_id)
  dataset_1_id = articles[0]['fields'].get('Datasets', None)
  dataset_2_id = articles[1]['fields'].get('Datasets', None)

  if not dataset_1_id and dataset_2_id:
    # No dataset associated with first article, but second has one
    # So delete the first article, nothing to delete in dataset or asana
    print(f"\tArticle {articles[0]['id']} can be deleted, no dataset associated")
    airtable.tables['Articles'].delete(articles[0]['id'])
    print(f"\tDeleted article {articles[0]['id']}")
    continue
  if dataset_1_id and not dataset_2_id:
    # No dataset associated with second article, but first has one
    # So delete the second article, nothing to delete in dataset or asana
    print(f"\tArticle {articles[1]['id']} can be deleted, no dataset associated")
    airtable.tables['Articles'].delete(articles[1]['id'])
    print(f"\tDeleted article {articles[1]['id']}")
    continue

  dataset_1_id = dataset_1_id[0]
  dataset_2_id = dataset_2_id[0]
  dataset_1 = datasets_dict[dataset_1_id]
  dataset_2 = datasets_dict[dataset_2_id]

  if (dataset_1['fields']['Status'] == "Awaiting Triage" and 
      dataset_2['fields']['Status'] == "Awaiting Triage"):
    # Both have same status. OK to delete
    # Delete the article first
    print("\tBoth datasets in 'Awaiting Triage'")
    airtable.tables['Articles'].delete(articles[0]['id'])
    print(f"\tDeleted article {articles[0]['id']}")
    

    # Get the dataset ID for Asana then delete the dataset second
    dataset_bpipd = dataset_1['fields']['Dataset ID']
    airtable.tables['Datasets'].delete(dataset_1_id)
    print(f"\tDeleted dataset {dataset_1_id}")

    # Then delete the asana task
    asana_task_id = tasks[dataset_bpipd]['gid']
    asana.tasks_api_instance.delete_task(asana_task_id)
    print(f"\tDeleted asana task {asana_task_id}")
    continue

  print("\tBoth status not 'Awaiting Triage', cannot automatically resolve")
  unprocessed_duplicates[article_id] = articles
# Out:
# 401829924
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article rec5fFKSD5jcN01aj
# 	Deleted dataset recChuld7zemNhI4t
# 	Deleted asana task 1212358224060409
# 267165813
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recA93KKPOwA6ZsaZ
# 	Deleted dataset recEp2TT8xz1H8alX
# 	Deleted asana task 1212332226168224
# 290423879
# 	Both status not 'Awaiting Triage', cannot automatically resolve
# 401834712
# 	Both status not 'Awaiting Triage', cannot automatically resolve
# 401841698
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recAcc4lLN1tsPmYY
# 	Deleted dataset recTaG53zXKHGpsVO
# 	Deleted asana task 1212284451182885
# 401817116
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recB0mdblsf5xdLwt
# 	Deleted dataset recSZ8cemJPUm10Bd
# 	Deleted asana task 1212335594205174
# 290417734
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recBAlRCn8qwZrXJe
# 	Deleted dataset recc1CZVHh0TZFlJF
# 	Deleted asana task 1212278547905088
# 401850709
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recBaW9Esp6CP0XBr
# 	Deleted dataset recsp7fV12oBct37Z
# 	Deleted asana task 1212336054014815
# 401837484
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recCBE5Pp1nh0qo9H
# 	Deleted dataset recXTGkbo7u83hHhG
# 	Deleted asana task 1212323994326234
# 401836848
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recCEJ5Y0B8iWQSm2
# 	Deleted dataset recDpLkXtUI2sCpo4
# 	Deleted asana task 1212324017027241
# 401850637
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recCXHI6Zv7COSdxa
# 	Deleted dataset recwom53jd5y3XpTf
# 	Deleted asana task 1212338647380137
# 401834468
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recD3QJ0Q2nsgoS9d
# 	Deleted dataset recTCLpK4lsk6U5zf
# 	Deleted asana task 1212336726321043
# 401846070
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recDaVhQ3braOgARj
# 	Deleted dataset rec9PdlHP3HaSW0r7
# 	Deleted asana task 1212351896849498
# 290423763
# 	Both status not 'Awaiting Triage', cannot automatically resolve
# 401850506
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recDgeSOtyByXe58b
# 	Deleted dataset rec3N3zgmZQNZV6MQ
# 	Deleted asana task 1212284460746012
# 215823339
# 	Article recEIXEkEvRcs77WP can be deleted, no dataset associated
# 	Deleted article recEIXEkEvRcs77WP
# 401857538
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recF4H0RtkGWSFcRm
# 	Deleted dataset recX6EvMEQiNI9F5d
# 	Deleted asana task 1212336609744329
# 401858315
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recF7TZChd3XY583k
# 	Deleted dataset recmNgMeOijaUIIml
# 	Deleted asana task 1212336163158589
# 401834083
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recFVFFTR3SdjLeSl
# 	Deleted dataset recEfFlSbgRNteTvc
# 	Deleted asana task 1212332211167564
# 401841913
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recG84Pyz9tipsyL2
# 	Deleted dataset recDF6IcN0i9LsPb1
# 	Deleted asana task 1212351981577463
# 401835162
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recGPR3Vk2tSEGEHR
# 	Deleted dataset reco0WA46DdHfcqiK
# 	Deleted asana task 1212295923664500
# 401843245
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recGVWOJTUeF2mXsm
# 	Deleted dataset recDcltKFeAAWkzeP
# 	Deleted asana task 1212351894333267
# 401831629
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recGr9LnBd5hsMEse
# 	Deleted dataset recvrY0r7aO6w3Vfc
# 	Deleted asana task 1212332210178474
# 401850410
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recGsQOyuElBhs1df
# 	Deleted dataset recng1r2yGkP7MUPy
# 	Deleted asana task 1212272585875045
# 401849024
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recH1FhHyUySTpD0x
# 	Deleted dataset recGCdi9GD0rmEddU
# 	Deleted asana task 1212272576167355
# 401842207
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recHbrUL1HxXPQ2Fs
# 	Deleted dataset recCrSoUA3lvMWVMQ
# 	Deleted asana task 1212351713241293
# 267166919
# 	Both status not 'Awaiting Triage', cannot automatically resolve
# 401854626
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recHwpvZchXCDrUbA
# 	Deleted dataset recGDnl3zH56wwxpF
# 	Deleted asana task 1212334754780624
# 401852794
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recIiywJYkcncwDN6
# 	Deleted dataset recJdd5tBKxZN8x1D
# 	Deleted asana task 1212338779335088
# 267162580
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recIlZrg65Rm6Qodi
# 	Deleted dataset recC7bMq9n84nGHaa
# 	Deleted asana task 1212336733203267
# 290417831
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recJccuaao0EgTyr4
# 	Deleted dataset rectHjmIQo65MVfK3
# 	Deleted asana task 1212273349165901
# 290416463
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recJk3xUxeXkXWCPp
# 	Deleted dataset recN50M1tVQJcTb0s
# 	Deleted asana task 1212353742049276
# 290427411
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recK8BPjrstm9EwT0
# 	Deleted dataset rec8MkXLsWQXxgrVb
# 	Deleted asana task 1212334751262760
# 401854061
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recK8tHdpfj92WLwe
# 	Deleted dataset recwBoTVnlMFZWXFw
# 	Deleted asana task 1212332239608972
# 290428449
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recKDepPhKxOsGnNJ
# 	Deleted dataset rec1XljxQJwt9C3W4
# 	Deleted asana task 1212295923573926
# 401841436
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recKTLE1QkrFXMybr
# 	Deleted dataset recyz4pwfpO27JY3M
# 	Deleted asana task 1212334753777344
# 401848159
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recKtWEPtotz7BsWB
# 	Deleted dataset rec5Q4d1FxJ4mggPi
# 	Deleted asana task 1212272576164472
# 401854014
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recKvETzd36TYDXzy
# 	Deleted dataset recbYSl00YNtY1HH4
# 	Deleted asana task 1212279759761057
# 401844603
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recL3CX7pWxmHg8DW
# 	Deleted dataset recRSJr3gJdCl1sG7
# 	Deleted asana task 1212351895816239
# 228147547
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recL5ErCoK0IppTOb
# 	Deleted dataset recDnTUOOJulKWgtI
# 	Deleted asana task 1212324015654251
# 267162083
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recLB9WjHoQzNsWCb
# 	Deleted dataset recLvdb08KyikAgZn
# 	Deleted asana task 1212278611756663
# 401829163
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recLH86krbfH7jhf7
# 	Deleted dataset recXAJa0dt5tQyrvE
# 	Deleted asana task 1212336723274744
# 267163477
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recLfaIQlh8WPBlBz
# 	Deleted dataset recCyS4dWitP5RGfu
# 	Deleted asana task 1212332240485276
# 401856167
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recLwDzNAPGNACWjn
# 	Deleted dataset recwCciHvhSK1xjua
# 	Deleted asana task 1212278547911042
# 401855427
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recMvahtPGp1DptwJ
# 	Deleted dataset recLbhFSPxXvU42Up
# 	Deleted asana task 1212278559391789
# 267163156
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recN83uQaBVdgPiE7
# 	Deleted dataset reclLUaX0mUKcYZxO
# 	Deleted asana task 1212284458245969
# 401837920
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recOmgOQ4Ptzl7RAR
# 	Deleted dataset recVVOCcGfPixMTBW
# 	Deleted asana task 1212332213272846
# 401849050
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recP9aQJNd0DKmm9h
# 	Deleted dataset recbYuAJcyIprcS1C
# 	Deleted asana task 1212336163035410
# 401843758
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recPKivoed53i0qgn
# 	Deleted dataset recJh7watYKF0uAHS
# 	Deleted asana task 1212332237719268
# 401853624
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recPYtswD0Z2VXkdY
# 	Deleted dataset rectMWFU1wzOHMf1L
# 	Deleted asana task 1212284460766544
# 267166712
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recPzqq0kHTCYygXg
# 	Deleted dataset recZoyjmWkjU0ea5s
# 	Deleted asana task 1212272576141265
# 401860725
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recQ59OmaNKkLhtS2
# 	Deleted dataset reccBveHTBtE5BMG3
# 	Deleted asana task 1212351335554771
# 401851545
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recQXfnfe14t9YxN7
# 	Deleted dataset recdutOGj2JaY6fnS
# 	Deleted asana task 1212336166142652
# 290422898
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recQxFt0Ope9yp0fF
# 	Deleted dataset recTvwQL3gFaQUdtU
# 	Deleted asana task 1212295154227456
# 401849106
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recRRVLPTweZeDIk5
# 	Deleted dataset rec85gGGR6M1RiE2A
# 	Deleted asana task 1212351719142821
# 401852137
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recRa3OZ7wfMD17bK
# 	Deleted dataset recebGH6zw3tEqt94
# 	Deleted asana task 1212336056113898
# 401851637
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recRrk4uu8lhaoJLf
# 	Deleted dataset recqnaJVinJuTTlIX
# 	Deleted asana task 1212348864132186
# 401833054
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recS8XE7g5jdPI2qo
# 	Deleted dataset recBlNiuZ7tqZ1N7M
# 	Deleted asana task 1212334748574716
# 401856111
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recSRzmwGvyT6DNyL
# 	Deleted dataset recpJQdrVO3fMo2gk
# 	Deleted asana task 1212307721570788
# 401832351
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recSZLWiPXByDtibh
# 	Deleted dataset recNJGfP36LjTElOv
# 	Deleted asana task 1212332211041243
# 401853618
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recT4n4hyKTXiqyaC
# 	Deleted dataset recwcl4UDpSws7AOK
# 	Deleted asana task 1212334753353522
# 401852747
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recTLJPRLOR9CX2Va
# 	Deleted dataset recdxXq5UlWjRGTT8
# 	Deleted asana task 1212278560297334
# 290415792
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recTV1EA586HNtPa8
# 	Deleted dataset recUGUGccuL9Uq8LQ
# 	Deleted asana task 1212332224413130
# 290415154
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recTYYbxW1mHq5LuF
# 	Deleted dataset recEbh9yvNuHLrqLY
# 	Deleted asana task 1212349600861686
# 216773918
# 	Article recTmfEY8fJ1X6kHt can be deleted, no dataset associated
# 	Deleted article recTmfEY8fJ1X6kHt
# 401855190
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recTu05zBeLrX0dbI
# 	Deleted dataset recT6jpc4MhqjrTah
# 	Deleted asana task 1212332241131154
# 401853944
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recUYlbknqsLP5GxE
# 	Deleted dataset recP0s85awxpI5SIJ
# 	Deleted asana task 1212336159613536
# 290416437
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recUquS6m7Vo2PFTr
# 	Deleted dataset recY5TAdRhbt1LFxK
# 	Deleted asana task 1212334748600287
# 290416850
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recUwrbKbQrNI2HIV
# 	Deleted dataset rec4p4bmQiDtD4Hq7
# 	Deleted asana task 1212332226186172
# 401849713
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recWNtH6GDcPIxiPH
# 	Deleted dataset rechOwfLvoMpvy9AQ
# 	Deleted asana task 1212336604016028
# 401839591
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recWW2qMSOFXmLVwM
# 	Deleted dataset recukqrFVsdUdIrAF
# 	Deleted asana task 1212332214765270
# 401853033
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recWrjB1aqphDQdPO
# 	Deleted dataset rec6TnpMdH1wbq0xW
# 	Deleted asana task 1212307721960311
# 401849805
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recY9VUWEYZO8rRAA
# 	Deleted dataset rec5mAtIYhBqqsVR1
# 	Deleted asana task 1212336056085939
# 267162243
# 	Both status not 'Awaiting Triage', cannot automatically resolve
# 401853567
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recZ0YPV37ep0jeDS
# 	Deleted dataset rec90RpkAnba3UFRY
# 	Deleted asana task 1212336059378400
# 401854355
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recbjQjzGpCpxB6Jy
# 	Deleted dataset rec52RgJSfEZd01WS
# 	Deleted asana task 1212278559368007
# 401851899
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recdO2pwGEbA6suK3
# 	Deleted dataset recjagJTmF1aTnmo6
# 	Deleted asana task 1212336054024863
# 401846079
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recdgHymXdsBr8UTw
# 	Deleted dataset recpOlaG4kmYzMXOW
# 	Deleted asana task 1212351984860200
# 290423307
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article receJpFFf4lJmPMTI
# 	Deleted dataset recY0WGyMM8TuUHcx
# 	Deleted asana task 1212336724177098
# 401833857
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recevoaQGoFTp4JNd
# 	Deleted dataset recLwZBV0C49oUjjW
# 	Deleted asana task 1212332210187336
# 290420569
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recfHy2UpOxhz745K
# 	Deleted dataset recI4N77IruOyKswu
# 	Deleted asana task 1212335214234706
# 267162847
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recfjk7lLQfem7dAY
# 	Deleted dataset recxZlrJHoCVNWo93
# 	Deleted asana task 1212295923570397
# 401849703
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article rechEfQvXhX8CkBGO
# 	Deleted dataset recHITINCSE1pzJT5
# 	Deleted asana task 1212336156216769
# 401841158
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article reci6bdzHwB85N2YB
# 	Deleted dataset recsyv1hJ1XKYsmGQ
# 	Deleted asana task 1212351979828111
# 401857692
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recimTMOWZW1SP9M4
# 	Deleted dataset reckpxTC45AgpH26v
# 	Deleted asana task 1212351724777289
# 290418232
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recixz6czFzGVQSAN
# 	Deleted dataset reclx81VBAPwBH1pK
# 	Deleted asana task 1212349600879171
# 401854918
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article reclP5udZTZ5KAW5k
# 	Deleted dataset rec4142OxSq4Nk5lC
# 	Deleted asana task 1212336731138181
# 267165785
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article reclhzZdTZLemDnIw
# 	Deleted dataset recCOMoL2tW4uj3O1
# 	Deleted asana task 1212332241151695
# 267163401
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article reclmz2ccNGtBsbS4
# 	Deleted dataset rec8iyWUEDMRTsBrs
# 	Deleted asana task 1212336737227222
# 401835995
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article reclseDMHu5mhD6E7
# 	Deleted dataset recbzZmKu74WldIQC
# 	Deleted asana task 1212332235158053
# 401842745
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recm41WEVBIVAfEoA
# 	Deleted dataset reccYlMsE3zkQzsqb
# 	Deleted asana task 1212332214798431
# 401850145
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recn1FJNDz2eYPZbM
# 	Deleted dataset recDCfv0FKN6rxLXo
# 	Deleted asana task 1212332240202670
# 401854683
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recrK0PaCwUrQzjro
# 	Deleted dataset recMFCLenIuiJkapb
# 	Deleted asana task 1212336742555649
# 401853432
# 	Both datasets in 'Awaiting Triage'
# 	Deleted article recszPXYnhfSSwNhy
# 	Deleted dataset recYa70I6rsA1oxV0
# 	Deleted asana task 1212278547857566

# %%
unprocessed_duplicates.keys()
# Out:
# dict_keys([290423879, 401834712, 290423763, 267166919, 267162243])
